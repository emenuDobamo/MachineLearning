# %%
from IPython.display import Image
Image(filename="Metropolitan_State_University_of_Denver_6270892.jpg",width=400,height=400)

# %% [markdown]
# # Machine Learning Assignment One

# %% [markdown]
# ## Emenu Dobamo

# %% [markdown]
# #### Prof. Beaty

# %% [markdown]
# ##### February 4, 2018,

# %% [markdown]
#  ## *Introduction to Machine learning*

# %% [markdown]
# - [what is Machine Learning?](##### what-is-Machine-learinig?)
# - Item 2a
# - Item 2b

# %% [markdown]
# ##### what is Machine learinig?

# %% [markdown]
# when people hear about machine learing, arteficial intelligence or anything related, they think about the rouge robot Cyberdyne Systems T-800. However that is not the case because machine learning gives us insight to the dataset. In this project we are going to work with the famous iris dataset to make some sense form the data. Machine learning is actively being used today. perhps in many more paces than you'd expect. search engiens show you relevant search results, spam filter catches unwanted ads,  netflix suggest movies based on you preference and the list go on and on. companies are using machine learing to improve business, increase productivity, forcast weather, detaect disease and do many more things.

# %% [markdown]
# This project will help you understand the basics of Machine learing.
